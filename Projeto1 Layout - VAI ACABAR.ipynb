# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## João Laet de Toledo Cesar
# ___

# %% [markdown]
# ## Pará vs Distrito Federal

# %% [markdown]
# ___
# ## O projeto irá analisar e comparar as tecnologias na telecomunicação em casas de alvenaria no estado do Pará e Distrito federal, sendo eles respectivamente, um dos menores e o maior IDH do país. Deste modo, será possível ver a discrepancia entre os dois.

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\João Laet\Documents\2° semestre\Ciencias dos Dados\PNAD's

# %% [markdown]
# # Criação Data Frame para 2015:

# %%
dados2015 = pd.read_csv('DOM2015.csv',sep=',')
df = pd.DataFrame({"TV_por_Assinatura":dados2015["V02272"],
                   "TV_Fina":dados2015["V02270"],
                   "Acesso_a_internet_em_casa":dados2015["V02322"],
                   "Usa_Celular_para_Internet":dados2015["V02324"],
                   "Tem_Smart_TV":dados2015["V02326"],
                   "Estado": dados2015["UF"],
                   "Material_construção": dados2015["V0203"],
                   "Tem_Tablet": dados2015["V02321"],
                   "Tem_Microcomputador": dados2015["V0231"]})

# %% [markdown]
# Colocando variáveis em "category" e colocando filtros:

# %%
sloq9 = df.TV_por_Assinatura.astype('category')
sloq9.cat.categories = (["Sim", "Não"])
slow9 = df.Acesso_a_internet_em_casa.astype('category')
slow9.cat.categories = (["Sim", "Não"])
sloe9 = df.Tem_Smart_TV.astype('category')
sloe9.cat.categories = (["Sim", "Não"])
slor9 = df.Usa_Celular_para_Internet.astype('category')
slor9.cat.categories = (["Sim", "Não"])
slot9 = df.Tem_Tablet.astype('category')
slot9.cat.categories = (["Sim", "Não"])
sloy9 = df.TV_Fina.astype('category')
sloy9.cat.categories = (["Nenhuma", "Uma", "Duas", "Três", "Quatro", "Cinco", "Seis", "Sete", "Oito", "Nove"])
slou9 = df.Tem_Microcomputador.astype('category')
slou9.cat.categories = (["Sim", "Não"])

dataframe = pd.DataFrame({"TV_por_Assinatura":sloq9,
                   "TV_Fina":sloy9,
                   "Acesso_a_internet_em_casa":slow9,
                   "Usa_Celular_para_Internet":slor9,
                   "Tem_Smart_TV":sloe9,
                   "Estado": dados2015["UF"],
                   "Material_construção": dados2015["V0203"],
                   "Tem_Tablet": slot9,
                   "Tem_Microcomputador":slou9})

a9 = dataframe[dataframe.Estado==15]
b9 = dataframe[dataframe.Estado==53]

c9 = a9[a9.Material_construção == 1]
d9 = b9[b9.Material_construção == 1]

# %% [markdown]
# Tirando e modificando os Nan:

# %%
c9[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]] = c9[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]].fillna(value="Não")
d9[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]] = d9[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]].fillna(value="Não")

dadosA9 = c9.dropna()
dadosDF9= d9.dropna()
# Out:
# C:\Insper\Anaconda3\lib\site-packages\pandas\core\frame.py:2440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# Salvando o Data Frame:

# %%
ParaSalvo9 = dadosA9.to_csv("Para.csv")
DFSalvo9 = dadosDF9.to_csv("DistritoFederal.csv")

# %%
ut19 = dadosA9.TV_Fina.value_counts(sort=False)
ut29 = dadosA9.TV_por_Assinatura.value_counts(sort=False)
ut39 = dadosA9.Acesso_a_internet_em_casa.value_counts(sort=False)
ut49 = dadosA9.Usa_Celular_para_Internet.value_counts(sort=False)
ut59 = dadosA9.Tem_Smart_TV.value_counts(sort=False)
ut69 = dadosA9.Tem_Tablet.value_counts(sort=False)
ut79 = dadosA9.Tem_Microcomputador.value_counts(sort=False)


DF19 = dadosDF9.TV_Fina.value_counts(sort=False)
DF29 = dadosDF9.TV_por_Assinatura.value_counts(sort=False)
DF39 = dadosDF9.Acesso_a_internet_em_casa.value_counts(sort=False)
DF49 = dadosDF9.Usa_Celular_para_Internet.value_counts(sort=False)
DF59 = dadosDF9.Tem_Smart_TV.value_counts(sort=False)
DF69 = dadosDF9.Tem_Tablet.value_counts(sort=False)
DF79 = dadosDF9.Tem_Microcomputador.value_counts(sort=False)

# %% [markdown]
# # Criação Data Frame para 2014:

# %%
dados2 = pd.read_csv('DOM2014.csv',sep=',')
df2 = pd.DataFrame({"TV_por_Assinatura":dados2["V02272"],
                   "TV_Fina":dados2["V02270"],
                   "Acesso_a_internet_em_casa":dados2["V02322"],
                   "Usa_Celular_para_Internet":dados2["V02324"],
                   "Tem_Smart_TV":dados2["V02326"],
                   "Estado": dados2["UF"],
                   "Material_construção": dados2["V0203"],
                   "Tem_Tablet": dados2["V02321"],
                   "Tem_Microcomputador": dados2["V0231"]})

# %% [markdown]
# Deixando Variáveis em "category" e colocando os filtros:

# %%
sloq2 = df2.TV_por_Assinatura.astype('category')
sloq2.cat.categories = (["Sim", "Não"])
slow2 = df2.Acesso_a_internet_em_casa.astype('category')
slow2.cat.categories = (["Sim", "Não"])
sloe2 = df2.Tem_Smart_TV.astype('category')
sloe2.cat.categories = (["Sim", "Não"])
slor2 = df2.Usa_Celular_para_Internet.astype('category')
slor2.cat.categories = (["Sim", "Não"])
slot2 = df2.Tem_Tablet.astype('category')
slot2.cat.categories = (["Sim", "Não"])
sloy2 = df2.TV_Fina.astype('category')
sloy2.cat.categories = (["Nenhuma", "Uma", "Duas", "Três", "Quatro", "Cinco", "Seis", "Sete", "Oito", "Nove", "Dez"])
slou2 = df2.Tem_Microcomputador.astype('category')
slou2.cat.categories = (["Sim", "Não"])

dataframe = pd.DataFrame({"TV_por_Assinatura":sloq2,
                   "TV_Fina":sloy2,
                   "Acesso_a_internet_em_casa":slow2,
                   "Usa_Celular_para_Internet":slor2,
                   "Tem_Smart_TV":sloe2,
                   "Estado": dados2["UF"],
                   "Material_construção": dados2["V0203"],
                   "Tem_Tablet": slot2,
                   "Tem_Microcomputador":slou2})

a2 = dataframe[dataframe.Estado==15]
b2 = dataframe[dataframe.Estado==53]

c2 = a2[a2.Material_construção == 1]
d2 = b2[b2.Material_construção == 1]

# %% [markdown]
# Filtrando e modificando os Nan:

# %%
c2[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]] = c2[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]].fillna(value="Não")
d2[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]] = d2[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]].fillna(value="Não")

dadosA2 = c2.dropna()
dadosDF2= d2.dropna()
# Out:
# C:\Insper\Anaconda3\lib\site-packages\pandas\core\frame.py:2440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# Salvando os Data Frames criados:

# %%
ParaSalvo2 = dadosA2.to_csv("Para.csv")
DFSalvo2 = dadosDF2.to_csv("DistritoFederal.csv")

# %%
ut12 = dadosA2.TV_Fina.value_counts(sort=False)
ut22 = dadosA2.TV_por_Assinatura.value_counts(sort=False)
ut32 = dadosA2.Acesso_a_internet_em_casa.value_counts(sort=False)
ut42 = dadosA2.Usa_Celular_para_Internet.value_counts(sort=False)
ut52 = dadosA2.Tem_Smart_TV.value_counts(sort=False)
ut62 = dadosA2.Tem_Tablet.value_counts(sort=False)
ut72 = dadosA2.Tem_Microcomputador.value_counts(sort=False)


DF12 = dadosDF2.TV_Fina.value_counts(sort=False)
DF22 = dadosDF2.TV_por_Assinatura.value_counts(sort=False)
DF32 = dadosDF2.Acesso_a_internet_em_casa.value_counts(sort=False)
DF42 = dadosDF2.Usa_Celular_para_Internet.value_counts(sort=False)
DF52 = dadosDF2.Tem_Smart_TV.value_counts(sort=False)
DF62 = dadosDF2.Tem_Tablet.value_counts(sort=False)
DF72 = dadosDF2.Tem_Microcomputador.value_counts(sort=False)

# %% [markdown]
# # Criação Data Frame para 2013:

# %%
dados = pd.read_csv('DOM2013.csv',sep=',')
df = pd.DataFrame({"TV_por_Assinatura":dados["V02272"],
                   "TV_Fina":dados["V02270"],
                   "Acesso_a_internet_em_casa":dados["V02322"],
                   "Usa_Celular_para_Internet":dados["V02324"],
                   "Tem_Smart_TV":dados["V02326"],
                   "Estado": dados["UF"],
                   "Material_construção": dados["V0203"],
                   "Tem_Tablet": dados["V02321"],
                   "Tem_Microcomputador": dados["V0231"]})

# %% [markdown]
# Deixando Variáveis em "category" e colocando os filtros:

# %%
sloq = df.TV_por_Assinatura.astype('category')
sloq.cat.categories = (["Sim", "Não"])
slow = df.Acesso_a_internet_em_casa.astype('category')
slow.cat.categories = (["Sim", "Não"])
sloe = df.Tem_Smart_TV.astype('category')
sloe.cat.categories = (["Sim", "Não"])
slor = df.Usa_Celular_para_Internet.astype('category')
slor.cat.categories = (["Sim", "Não"])
slot = df.Tem_Tablet.astype('category')
slot.cat.categories = (["Sim", "Não"])
sloy = df.TV_Fina.astype('category')
sloy.cat.categories = (["Nenhuma", "Uma", "Duas", "Três", "Quatro", "Cinco", "Seis", "Sete", "Oito", "Nove"])
slou = df.Tem_Microcomputador.astype('category')
slou.cat.categories = (["Sim", "Não"])

dataframe = pd.DataFrame({"TV_por_Assinatura":sloq,
                   "TV_Fina":sloy,
                   "Acesso_a_internet_em_casa":slow,
                   "Usa_Celular_para_Internet":slor,
                   "Tem_Smart_TV":sloe,
                   "Estado": dados["UF"],
                   "Material_construção": dados["V0203"],
                   "Tem_Tablet": slot,
                   "Tem_Microcomputador":slou})

a = dataframe[dataframe.Estado==15]
b = dataframe[dataframe.Estado==53]

c = a[a.Material_construção == 1]
d = b[b.Material_construção == 1]

# %% [markdown]
# Tirando e modificando os Nan:

# %%
c[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]] = c[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]].fillna(value="Não")
d[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]] = d[['Acesso_a_internet_em_casa', 'Tem_Smart_TV', "TV_por_Assinatura", "Usa_Celular_para_Internet"]].fillna(value="Não")

dadosA = c.dropna()
dadosDF= d.dropna()
# Out:
# C:\Insper\Anaconda3\lib\site-packages\pandas\core\frame.py:2440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# Salvando o Data Frame:

# %%
ParaSalvo = dadosA.to_csv("Para.csv")
DFSalvo = dadosDF.to_csv("DistritoFederal.csv")

# %%
ut1 = dadosA.TV_Fina.value_counts(sort=False)
ut2 = dadosA.TV_por_Assinatura.value_counts(sort=False)
ut3 = dadosA.Acesso_a_internet_em_casa.value_counts(sort=False)
ut4 = dadosA.Usa_Celular_para_Internet.value_counts(sort=False)
ut5 = dadosA.Tem_Smart_TV.value_counts(sort=False)
ut6 = dadosA.Tem_Tablet.value_counts(sort=False)
ut7 = dadosA.Tem_Microcomputador.value_counts(sort=False)


DF1 = dadosDF.TV_Fina.value_counts(sort=False)
DF2 = dadosDF.TV_por_Assinatura.value_counts(sort=False)
DF3 = dadosDF.Acesso_a_internet_em_casa.value_counts(sort=False)
DF4 = dadosDF.Usa_Celular_para_Internet.value_counts(sort=False)
DF5 = dadosDF.Tem_Smart_TV.value_counts(sort=False)
DF6 = dadosDF.Tem_Tablet.value_counts(sort=False)
DF7 = dadosDF.Tem_Microcomputador.value_counts(sort=False)

# %% [markdown]
# # Plotando os gráficos:

# %%
plt.subplot(131)
plot = ut1.plot(kind='bar',title='TV Fina no Pará 2013',figsize=(20,5),color=('b'))
plt.ylabel('Quantidade pessoas')
plt.xlabel('números de Televisões')
plt.subplot(132)
plot = DF1.plot(kind='bar',title='TV Fina no Distrito Federal 2013',figsize=(20, 5),color=('r'))
plt.ylabel('Quantidade pessoas')
plt.xlabel('números de Televisões')
plt.show()

plt.subplot(131)
plot = ut12.plot(kind='bar',title='TV Fina no Pará 2014',figsize=(20,5),color=('b'))
plt.ylabel('Quantidade pessoas')
plt.xlabel('números de Televisões')
plt.subplot(132)
plot = DF12.plot(kind='bar',title='TV Fina no Distrito Federal 2014',figsize=(20,5),color=('r'))
plt.ylabel('Quantidade pessoas')
plt.xlabel('números de Televisões')
plt.show()

plt.subplot(131)
plot = ut19.plot(kind='bar',title='TV Fina no Pará 2015',figsize=(20,5),color=('b'))
plt.ylabel('Quantidade pessoas')
plt.xlabel('números de Televisões')
plt.subplot(132)
plot = DF19.plot(kind='bar',title='TV Fina no Distrito Federal 2015',figsize=(20,5),color=('r'))
plt.ylabel('Quantidade pessoas')
plt.xlabel('números de Televisões')
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut2.plot(kind='pie',title='TV por Assinatura (Pará) 2013',autopct='%.1f')
plt.subplot(132)
plot = DF2.plot(kind='pie',title='TV por Assinatura (DF) 2013',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut22.plot(kind='pie',title='TV por Assinatura (Pará) 2014',autopct='%.1f')
plt.subplot(132)
plot = DF22.plot(kind='pie',title='TV por Assinatura (DF) 2014',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut29.plot(kind='pie',title='TV por Assinatura (Pará) 2015',autopct='%.1f')
plt.subplot(132)
plot = DF29.plot(kind='pie',title='TV por Assinatura (DF) 2015',autopct='%.1f')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut3.plot(kind='pie',title='Acesso a Internet em Casa (Pará) 2013',autopct='%.1f')
plt.subplot(132)
plot = DF3.plot(kind='pie',title='Acesso a Internet em Casa (DF) 2013',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut32.plot(kind='pie',title='Acesso a Internet em Casa (Pará) 2014',autopct='%.1f')
plt.subplot(132)
plot = DF32.plot(kind='pie',title='Acesso a Internet em Casa (DF) 2014',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut39.plot(kind='pie',title='Acesso a Internet em Casa (Pará) 2015',autopct='%.1f')
plt.subplot(132)
plot = DF39.plot(kind='pie',title='Acesso a Internet em Casa (DF) 2015',autopct='%.1f')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut4.plot(kind='pie',title='Celular para acessar Internet (Pará) 2013',autopct='%.1f')
plt.subplot(132)
plot = DF4.plot(kind='pie',title='Celular para acessar Internet (DF) 2013',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut42.plot(kind='pie',title='Celular para acessar Internet (Pará) 2014',autopct='%.1f')
plt.subplot(132)
plot = DF42.plot(kind='pie',title='Celular para acessar Internet (DF) 2014',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut49.plot(kind='pie',title='Celular para acessar Internet (Pará) 2015',autopct='%.1f')
plt.subplot(132)
plot = DF49.plot(kind='pie',title='Celular para acessar Internet (DF) 2015',autopct='%.1f')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut5.plot(kind='pie',title='TV para acessar Internet (Pará) 2013',autopct='%.1f')
plt.subplot(132)
plot = DF5.plot(kind='pie',title='TV para acessar Internet (DF) 2013',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut52.plot(kind='pie',title='TV para acessar Internet (Pará) 2014',autopct='%.1f')
plt.subplot(132)
plot = DF52.plot(kind='pie',title='TV para acessar Internet (DF) 2014',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut59.plot(kind='pie',title='TV para acessar Internet (Pará) 2015',autopct='%.1f')
plt.subplot(132)
plot = DF59.plot(kind='pie',title='TV para acessar Internet (DF) 2015',autopct='%.1f')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut6.plot(kind='pie',title='Tem Tablet (Pará) 2013',autopct='%.1f')
plt.subplot(132)
plot = DF6.plot(kind='pie',title='Tem Tablet (DF) 2013',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut62.plot(kind='pie',title='Tem Tablet (Pará) 2014',autopct='%.1f')
plt.subplot(132)
plot = DF62.plot(kind='pie',title='Tem Tablet (DF) 2014',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut69.plot(kind='pie',title='Tem Tablet (Pará) 2015',autopct='%.1f')
plt.subplot(132)
plot = DF69.plot(kind='pie',title='Tem Tablet (DF) 2015',autopct='%.1f')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut7.plot(kind='pie',title='Tem Microcomputador (Pará) 2013',autopct='%.1f')
plt.subplot(132)
plot = DF7.plot(kind='pie',title='Tem Microcomputador (DF) 2013',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut72.plot(kind='pie',title='Tem Microcomputador (Pará) 2014',autopct='%.1f')
plt.subplot(132)
plot = DF72.plot(kind='pie',title='Tem Microcomputador (DF) 2014',autopct='%.1f')
plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(15, 5))
plt.subplot(131)
plot = ut79.plot(kind='pie',title='Tem Microcomputador (Pará) 2015',autopct='%.1f')
plt.subplot(132)
plot = DF79.plot(kind='pie',title='Tem Microcomputador (DF) 2015',autopct='%.1f')
plt.tight_layout()
plt.show()

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Com a utilização dos gráficos plotados, foi possível ver a diferença entre o uso das tecnologias entre o estado do Pará e o Distrito Federal. Apesar da diferença, foi visto também um aumento crescimento nas tecnologias em ambos estados ao decorrer dos anos.
