# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## João Laet de Toledo Cesar
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\João Laet\Documents\2° semestre\Ciencias dos Dados\PNAD's

# %%
dados = pd.read_csv('DOM2013.csv',sep=',')
df = pd.DataFrame({"TV_por_Assinatura":dados["V02272"],
                   "TV_Fina":dados["V02270"],
                   "Acesso_a_internet_em_casa":dados["V02322"],
                   "Usa_Celular_para_Internet":dados["V02324"],
                   "Tem_Smart_TV":dados["V02326"],
                   "Estado": dados["UF"],
                   "Material_construção": dados["V0203"],
                   "Tem_Tablet": dados["V02321"],
                   "Tem_Microcomputador": dados["V0231"]})

# %%
sloq = df.TV_por_Assinatura.astype('category')
sloq.cat.categories = (["Sim", "Não"])
slow = df.Acesso_a_internet_em_casa.astype('category')
slow.cat.categories = (["Sim", "Não"])
sloe = df.Tem_Smart_TV.astype('category')
sloe.cat.categories = (["Sim", "Não"])
slor = df.Usa_Celular_para_Internet.astype('category')
slor.cat.categories = (["Sim", "Não"])
slot = df.Tem_Tablet.astype('category')
slot.cat.categories = (["Sim", "Não"])
sloy = df.TV_Fina.astype('category')
sloy.cat.categories = (["Nenhuma", "Uma", "Duas", "Três", "Quatro", "Cinco", "Seis", "Sete", "Oito", "Nove"])
slou = df.Tem_Microcomputador.astype('category')
slou.cat.categories = (["Sim", "Não"])
#sloi = df.Material_construção.astype('category')
#sloi.cat.categories = (["Alvenaria","Madeira aparelhada", "Taipa não revestida", "Madeira aproveitada", "Palha", "Outro material"])

dataframe = pd.DataFrame({"TV_por_Assinatura":sloq,
                   "TV_Fina":slot,
                   "Acesso_a_internet_em_casa":slow,
                   "Usa_Celular_para_Internet":slor,
                   "Tem_Smart_TV":sloe,
                   "Estado": dados["UF"],
                   "Material_construção": dados["V0203"],
                   "Tem_Tablet": slot,
                   "Tem_Microcomputador":slou})


a = dataframe[dataframe.Estado==16]
b = dataframe[dataframe.Estado==53]

c = a[a.Material_construção==1]
d = b[b.Material_construção==1]
c
# Out:
#       Acesso_a_internet_em_casa  Estado  Material_construção TV_Fina  \
# 17794                       Não      16                  1.0     Não
# 17795                       Sim      16                  1.0     Não
# 17796                       Sim      16                  1.0     Não
# 17799                       Sim      16                  1.0     Não
# 17801                       Não      16                  1.0     Não
# 17802                       Sim      16                  1.0     Não
# 17804                       Não      16                  1.0     Não
# 17807                       Não      16                  1.0     Não
# 17811                       Sim      16                  1.0     Não
# 17812                       Não      16                  1.0     Não
# 17814                       Sim      16                  1.0     Não
# 17816                       Sim      16                  1.0     Não
# 17818                       Não      16                  1.0     Não
# 17820                       Não      16                  1.0     Não
# 17822                       Não      16                  1.0     Não
# 17823                       Não      16                  1.0     Não
# 17825                       Não      16                  1.0     Não
# 17855               Não                 Não          NaN        Não
# 17856               Não                 Não          NaN        Não
# 17858               Não                 Sim          Não        Não
# 17885               Não                 Não          NaN        Não
# 17889               Não                 Sim          Não        Não
# 17894               Sim                 Não          Não        Não
# ...                 ...                 ...          ...        ...
# 18664               Sim                 Sim          Não        Sim
# 18674               Sim                 Sim          Não        Não
# 18675               Não                 Não          NaN        Não
# 18676               Sim                 Sim          Não        Não
# 18677               Não                 Não          NaN        Não
# 18678               Não                 Sim          Não        Não
# 18679               Sim                 Sim          Não        Não
# 18680               Não                 Não          NaN        Não
# 18686               Não                 Não          NaN        Não
# 18687               Não                 Não          NaN        Não
# 18688               Não                 Não          NaN        Não
# 18689               Não                 Sim          Não        Não
# 18690               Sim                 Sim          Não        Não
# 18691               Não                 Não          NaN        Não
# 18694               Não                 Não          Não        Não
# 18698               Não                 Sim          Não        Não
# 18699               Não                 Não          Não        Não
# 18701               Sim                 Sim          Não        Não
# 18710               Não                 Não          NaN        Não
# 18711               Não                 Não          NaN        Não
# 18712               Não                 Não          NaN        Não
# 18713               Não                 Não          NaN        Não
# 18714               Sim                 Não          NaN        Não
# 18715               Sim                 Não          NaN        Não
# 18718               Sim                 Sim          NaN        Não
# 18719               Sim                 Sim          Não        Sim
# 18721               Sim                 Não          NaN        Não
# 18723               Sim                 Não          NaN        Não
# 18724               Sim                 Sim          NaN        Sim
# 18726               Não                 Não          NaN        Não
#
#       Usa_Celular_para_Internet
# 17794                       NaN
# 17795                       Sim
# 17796                       Sim
# 17799                       Sim
# 17801                       NaN
# 17802                       Sim
# 17804                       NaN
# 17807                       NaN
# 17811                       Sim
# 17812                       NaN
# 17814                       Sim
# 17816                       Sim
# 17818                       NaN
# 17820                       NaN
# 17822                       NaN
# 17823                       NaN
# 17825                       NaN
# 17826                       NaN
# 17828                       NaN
# 17830                       NaN
# 17834                       NaN
# 17836                       NaN
# 17842                       NaN
# 17849                       NaN
# 17855                       NaN
# 17856                       NaN
# 17858                       Não
# 17885                       NaN
# 17889                       Não
# 17894                       Sim
# ...                         ...
# 18664                       Sim
# 18674                       Sim
# 18675                       NaN
# 18676                       Sim
# 18677                       NaN
# 18678                       Sim
# 18679                       Sim
# 18680                       NaN
# 18686                       NaN
# 18687                       NaN
# 18688                       NaN
# 18689                       Não
# 18690                       Não
# 18691                       NaN
# 18694                       Sim
# 18698                       Sim
# 18699                       Sim
# 18701                       Sim
# 18710                       NaN
# 18711                       NaN
# 18712                       NaN
# 18713                       NaN
# 18714                       NaN
# 18715                       NaN
# 18718                       NaN
# 18719                       Sim
# 18721                       NaN
# 18723                       NaN
# 18724                       NaN
# 18726                       NaN
#
# [438 rows x 9 columns]

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
